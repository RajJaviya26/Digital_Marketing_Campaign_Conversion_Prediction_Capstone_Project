# %% [markdown]
# # <div style="text-align:center; border-radius:15px 50px; padding:7px; color:white; margin:0; font-size:110%; font-family:Pacifico; background-color:#0073e6; overflow:hidden"><b> Machine learning - Customer Conversion Prediction</b></div>

# %% [markdown]
# <!--[](https://img.freepik.com/vetores-gratis/pagina-de-destino-do-marketing-digital_33099-1726.jpg?t=st=1724162688~exp=1724166288~hmac=8858e926e48b2f568ab1d96b7b43e3494e318657a24cd9ba9d5d68f87a59d297&w=1800)-->
# <img src="https://img.freepik.com/vetores-gratis/pagina-de-destino-do-marketing-digital_33099-1726.jpg" width="1800">

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color: #30914a; font-size:120%; text-align:left">
#
# <h3 align="left"><font color=red>Problem:</font></h3>
#
# The compan struggles to target the right customers, leading to wasted ad spend and ineffective campaigns. Without a data-driven approach, the business is missing opportunities to improve conversion rates and optimize marketing performance, resulting in higher costs and lower returns on marketing investments. The company needs a solution to predict customer conversion likelihoods more accurately to focus efforts on high-potential leads and improve overall campaign efficiency.

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color: #30914a; font-size:115%; text-align:left">
#
# <h3 align="left"><font color=red>Objectives:</font></h3>
#
# * __Explore the Dataset__: Uncover patterns, distributions, and relationships within the data.
# * __Conduct Extensive Exploratory Data Analysis (EDA)__: Dive deep into univariate, bivariate relationships against the target.
# * __Preprocessing Steps__:
#   - Remove irrelevant features
#   - Address missing values
#   - Treat outliers
#   - Encode categorical variables
#   - Transform skewed features to achieve normal-like distributions
# * __Model Building__:
#   - Establish models for prediction
#   - Implement and tune classification models including Logistic Regression, SVM, Decision Trees, and Random Forest,     Gradient Boost, AdaBoost, and Bagging Classifier
#   - Emphasize achieving high recall for class 1, ensuring comprehensive identification of heart patients
# * __Evaluate and Compare Model Performance__: Utilize precision, recall, and F1-score to gauge models' effectiveness.

# %% [markdown]
# <a id="contents_tabel"></a>
# <div style="border-radius:10px; padding: 15px; background-color: #30914a; font-size:115%; text-align:left">
#
# <h3 align="left"><font color=red><b>Table of Contents:</b></font></h3>
#
# * [Step 1 | Import Libraries](#step-1--import-libraries)
# * [Step 2 | Read Dataset](#step-2--read-dataset)
# * [Step 3 | Data Overview cum Preprocessing](#overview)
#     - [Step 3.1 | Check Data](#31-check-data)
#     - [Step 3.2 | Check number of rows and columns](#32-check-number-of-rows-and-columns)
#     - [Step 3.3 | Check for Datatype](#33-check-for-datatype)
#     - [Step 3.4 | Count Category](#34-count-categories)
#     - [Step 3.5 | Drop unnecessary Columns](#35-drop-unnecessary-columns)
#     - [Step 3.6 | Statistical Information of the Dataset](#36-statistical-information-of-the-dataset)
#     - [Step 3.7 | Check for outliers in numerical Columns](#37-check-for-outliers-in-numerical-columns)
#
# * [Step 4 | EDA](#step-4--eda)
#     - [Step 4.1 | Univariate Analysis](#41-univariate-analysis)
#         - [Step 4.1.1 | Numerical Variables Univariate Analysis](#411-numerical-variables-univariate-analysis)
#         - [Step 4.1.2 | Categorical Variables Univariate Analysis](#412-categorical-variables-univariate-analysis)
#     - [Step 4.2 | Bivariate Analysis](#42-bivariate-analysis)
#         - [Step 4.2.1 | Analyzing Adspend to Conversion](#421-analyzing-adspend-to-conversion-analysis)
#         - [Step 4.2.2 | Analyzing Campaign Channel to gender](#422-analyzing-campaign-channnel-to-gender)
#         - [Step 4.2.3 | Analyzing Campaign type to gender](#423-analyzing-campaign-type-to-gender)
#         - [Step 4.2.4 | Analyzing Age to Convertion](#424-analyzing-age-to-converesion-kde)
#         - [Step 4.2.5 | Analyzing Previous Purchase Imapact on Conversion](#425-analyzing-previous-purchases-impact-on-conversion)
#         - [Step 4.2.6 | Analyzing Loyalty Points impact on Conversion](#426-analyzing-loyalty-points-impact-on-conversion)
#         - [Step 4.2.7 | Analyzing Campaign Channel to Conversion](#427-analyzing-campaign-channel-to-conversion)
#         - [Step 4.2.8 | Analyzing Campaign Type to Conversion](#428-analyzing-campaign-type-to-convertion)
#     - [Step 4.3 | Analysis of the Campaign type, Gender, Campaign Channel and Conversion](#429-analysis-of-the-campaign-type-gender-campaign-channel-and-the-conversion-data-columns)
# * [Step 5 | Feature Engineering](#step-5--feature-engineering)
#     - [Step 5.1 | Seperate Data in Features and Target](#51-seperate-data-in-features-and-target)
#     - [Step 5.2 | Scaling of Numeric Column in Feature](#52-scaling-of-numeric-columns-in-feature)
#     - [Step 5.3 | Encoding of the Categorical Column in Features](#53-encoding-cateorical-columns-in-features)
#     - [Step 5.4 | Correlation Metrics](#54-correlation-metrics)
#     - [Step 5.5 | Handling Imbalance](#55-handling-imbalance)
#     - [Step 5.6 | Split data into Train and Test](#54-split-data-into-train-and-test)
# * [Step 6 | Model Selection](#step-6---model-selection)
#     - [Step 6.1 | Model Evaluation Function](#61-model-evaluation-function)
#     - [Step 6.2 | Model Building](#62-model-building)
#         - [Step 6.2.1 | Logistic Regresssion](#621-logistic-regression)
#         - [Step 6.2.2 | Support Vector Machine](#622-support-vector-machine)
#         - [Step 6.2.3 | Decision Tree](#623-decision-tree)
#         - [Step 6.2.4 | Random Forest](#624-random-forest)
#         - [Step 6.2.5 | Gradient Boosting](#625-gradient-boosting)
#         - [Step 6.2.6 | Ada Boost](#626-adaboost)
#         - [Step 6.2.7 | Bagging Classifier](#627-bagging-classifier)
#     -[Step 6.3 | Model Comparision](#63-model-comparision)
#     - [Step 6.3.1 | Accuracy Comparision](#631-model-accuracy-comparison)
#     - [Step 6.3.2 | F1 Score Comparision](#631-model-f1-score-comparison)
# * [Step 7 | Save Model](#step-7--save-model)
# * [Step 8 | Model Deployment](#step-8--model-deployment)

# %% [markdown]
# ### <p style="background-color:yellow; font-family:calibri; color:red; font-size:150%; text-align:center; border-radius:50px 50px;">Step 1 | Import Libraries</p>

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, GridSearchCV , cross_val_score
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier, BaggingClassifier
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, roc_curve, precision_recall_curve, auc, f1_score, accuracy_score, average_precision_score
# from imblearn.over_sampling import SMOTE
from imblearn.combine import SMOTETomek
import joblib
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### <p style="background-color:yellow; font-family:calibri; color:red; font-size:150%; text-align:center; border-radius:50px 50px;">Step 2 | Read Dataset</p>

# %%
# Load and inspect data
df = pd.read_csv('digital_marketing_campaign_dataset.csv')

# %% [markdown]
# ### <p style="background-color:yellow; font-family:calibri; color:red; font-size:150%; text-align:center; border-radius:50px 50px;"> Step 3 | Data Overview cum Preprocessing</p>

# %% [markdown]
# > #### 3.1 Check Data

# %%
df.head()
# Out:
#    CustomerID  Age  Gender  Income CampaignChannel CampaignType      AdSpend  \
# 0        8000   56  Female  136912    Social Media    Awareness  6497.870068
# 1        8001   69    Male   41760           Email    Retention  3898.668606
# 2        8002   46  Female   88456             PPC    Awareness  1546.429596
# 3        8003   32  Female   44085             PPC   Conversion   539.525936
# 4        8004   60  Female   83964             PPC   Conversion  1678.043573
#
#    ClickThroughRate  ConversionRate  WebsiteVisits  PagesPerVisit  TimeOnSite  \
# 0          0.043919        0.088031              0       2.399017    7.396803
# 1          0.155725        0.182725             42       2.917138    5.352549
# 2          0.277490        0.076423              2       8.223619   13.794901
# 3          0.137611        0.088004             47       4.540939   14.688363
# 4          0.252851        0.109940              0       2.046847   13.993370
#
# ...

# %%
df.tail()
# Out:
#       CustomerID  Age  Gender  Income CampaignChannel   CampaignType  \
# 7995       15995   21    Male   24849           Email      Awareness
# 7996       15996   43  Female   44718             SEO      Retention
# 7997       15997   28  Female  125471        Referral  Consideration
# 7998       15998   19  Female  107862             PPC  Consideration
# 7999       15999   31  Female   93002           Email      Awareness
#
#           AdSpend  ClickThroughRate  ConversionRate  WebsiteVisits  \
# 7995  8518.308575          0.243792        0.116773             23
# 7996  1424.613446          0.236740        0.190061             49
# 7997  4609.534635          0.056526        0.133826             35
# 7998  9476.106354          0.023961        0.138386             49
# 7999  7743.627070          0.185670        0.057228             15
#
#       PagesPerVisit  TimeOnSite  SocialShares  EmailOpens  EmailClicks  \
# 7995       9.693602   14.227794            70          13            6
# ...

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color: #30914a; font-size:120%; text-align:left">
#
# <h2 align="left"><font color=red>Dataset Description:</font></h2>
#
# | __Variable__ | __Description__ |
# |     :---      |       :---      |
# | __CustomerID__ | Unique identifier for each customer. |
# | __Age__ | Age of the customer. |
# | __Gender__ | Gender of the customer (Male/Female) |
# | __Income__ | Annual income of the customer in USD |
# | __CampaignChannel__ | The channel through which the marketing campaign is delivered (Email, Social Media, SEO, PPC, Referral). |
# | __CampaignType__ | Type of the marketing campaign (Awareness, Consideration, Conversion, Retention) |
# | __AdSpend__ | Amount spent on the marketing campaign in USD |
# | __ClickThroughRate__ | Rate at which customers click on the marketing content |
# | __ConversionRate__ | Rate at which clicks convert to desired actions (e.g., purchases). |
# | __WebsiteVisits__ | Number of visits to the website |
# | __PagesPerVisit__ | Average number of pages visited per session |
# | __TimeOnSite__ | Average time spent on the website per visit (in minutes) |
# | __SocialShares__ | Number of times the marketing content was shared on social media |
# | __EmailOpens__ | Number of times marketing emails were opened |
# | __EmailClicks__ | Number of times links in marketing emails were clicked |
# | __PreviousPurchases__ | Number of previous purchases made by the customer |
# | __LoyaltyPoints__ | Number of loyalty points accumulated by the customer |
# | __AdvertisingPlatform__ | Confidential |
# | __AdvertisingTool__ | Confidential |
# | __Conversion__ | Binary variable indicating whether the customer converted (1) or not (0) |

# %% [markdown]
# #### 3.2 Check number of rows and columns

# %%
df.shape
# Out:
# (8000, 20)

# %% [markdown]
# There are 8000 rows and 80 columns in Dataset.

# %% [markdown]
# #### 3.3 Check for Datatype

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8000 entries, 0 to 7999
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   CustomerID           8000 non-null   int64
#  1   Age                  8000 non-null   int64
#  2   Gender               8000 non-null   object
#  3   Income               8000 non-null   int64
#  4   CampaignChannel      8000 non-null   object
#  5   CampaignType         8000 non-null   object
#  6   AdSpend              8000 non-null   float64
#  7   ClickThroughRate     8000 non-null   float64
#  8   ConversionRate       8000 non-null   float64
#  9   WebsiteVisits        8000 non-null   int64
#  10  PagesPerVisit        8000 non-null   float64
#  11  TimeOnSite           8000 non-null   float64
#  12  SocialShares         8000 non-null   int64
#  13  EmailOpens           8000 non-null   int64
#  14  EmailClicks          8000 non-null   int64
# ...

# %% [markdown]
# #### Inferences:
#
# * __Number of Entries__: The dataset consists of __8000 entries__.
#
#
# * __Columns__: There are __20 columns__ in the dataset corresponding to various attributes of the Demographic Information, Marketing-specific Variables, Customer Engagement Variables, Historical Data and Target Variable.
#
#
# * __Data Types__:
#     - Most of the columns (9 out of 19) are of the __int64__ data type.
#     - Other 5 ,5 columns are of the float64 and object data type respectively.
#
#
# * __Missing Values__: There don't appear to be any missing values in the dataset as each column has 8000 non-null entries.

# %% [markdown]
# #### 3.4 Count Categories

# %%
df['AdvertisingTool'].value_counts()
# Out:
# AdvertisingTool
# ToolConfid    8000
# Name: count, dtype: int64

# %%
df['AdvertisingTool'].value_counts()
# Out:
# AdvertisingTool
# ToolConfid    8000
# Name: count, dtype: int64

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Female    4839
# Male      3161
# Name: count, dtype: int64

# %%
df['CampaignType'].value_counts()
# Out:
# CampaignType
# Conversion       2077
# Awareness        1988
# Consideration    1988
# Retention        1947
# Name: count, dtype: int64

# %%
df['CampaignChannel'].value_counts()
# Out:
# CampaignChannel
# Referral        1719
# PPC             1655
# Email           1557
# SEO             1550
# Social Media    1519
# Name: count, dtype: int64

# %% [markdown]
# #### 3.5 Drop Unnecessary Columns

# %% [markdown]
# ##### Drop unnecessary Columns like AdvertisingPlatform and AdvertisingTool as it is Confidential and CustomerID it does not affect Prediction or Conversion.

# %%
df.drop(columns= ['AdvertisingPlatform', 'CustomerID', 'AdvertisingTool'], axis= 1, inplace= True)

# %% [markdown]
# Check after Dropping columns

# %%
df.head()
# Out:
#    Age  Gender  Income CampaignChannel CampaignType      AdSpend  \
# 0   56  Female  136912    Social Media    Awareness  6497.870068
# 1   69    Male   41760           Email    Retention  3898.668606
# 2   46  Female   88456             PPC    Awareness  1546.429596
# 3   32  Female   44085             PPC   Conversion   539.525936
# 4   60  Female   83964             PPC   Conversion  1678.043573
#
#    ClickThroughRate  ConversionRate  WebsiteVisits  PagesPerVisit  TimeOnSite  \
# 0          0.043919        0.088031              0       2.399017    7.396803
# 1          0.155725        0.182725             42       2.917138    5.352549
# 2          0.277490        0.076423              2       8.223619   13.794901
# 3          0.137611        0.088004             47       4.540939   14.688363
# 4          0.252851        0.109940              0       2.046847   13.993370
#
#    SocialShares  EmailOpens  EmailClicks  PreviousPurchases  LoyaltyPoints  \
# ...

# %% [markdown]
# #### 3.6 Statistical Information of the Dataset

# %%
df.describe().T
# Out:
#                     count          mean           std           min  \
# Age                8000.0     43.625500     14.902785     18.000000
# Income             8000.0  84664.196750  37580.387945  20014.000000
# AdSpend            8000.0   5000.944830   2838.038153    100.054813
# ClickThroughRate   8000.0      0.154829      0.084007      0.010005
# ConversionRate     8000.0      0.104389      0.054878      0.010018
# WebsiteVisits      8000.0     24.751625     14.312269      0.000000
# PagesPerVisit      8000.0      5.549299      2.607358      1.000428
# TimeOnSite         8000.0      7.727718      4.228218      0.501669
# SocialShares       8000.0     49.799750     28.901165      0.000000
# EmailOpens         8000.0      9.476875      5.711111      0.000000
# EmailClicks        8000.0      4.467375      2.856564      0.000000
# PreviousPurchases  8000.0      4.485500      2.888093      0.000000
# LoyaltyPoints      8000.0   2490.268500   1429.527162      0.000000
# ...

# %% [markdown]
# ##### Here are some concise observations based on the descriptive statistics of the dataset:
#
# > a. Age: Mean and median are around 43.6, indicating a symmetric distribution.
#
# > b. Income: Mean is 84,664 dollars with a median of 84,926.50 dollars, showing a balanced income distribution.
#
# > c. Ad Spend: Mean and median are both about 5,000 dollars, suggesting a symmetric distribution.
#
# > d. Click Through Rate (CTR): Mean and median are 0.1548 and 0.1545 respectively, indicating no extreme outliersindicating a symmetric distribution..
#
# > e. Conversion Rate: Mean and median are 0.1044 and 0.104, showing a symmetric distribution.
#
# > f. Website Visits: Mean is 24.75 with a median of 25, indicating symmetry.
#
# > g. Pages Per Visit: Mean and median are both around 5.55, suggesting a balanced distribution.
#
# > h. Time on Site: Mean and median are 7.73 and 7.68 minutes, respectively, indicating symmetry.
#
# > i. Social Shares: Mean is 49.8 with a median of 50, showing a balanced distribution.
#
# > j. Email Opens and Clicks: Both have means and medians close to each other, indicating symmetric distributions.
#
# > k. Previous Purchases: Mean is 4.49 with a median of 4, suggesting balance.
#
# > l. Loyalty Points: Mean and median are both around 2,490, indicating a symmetric distribution.

# %% [markdown]
# #### 3.7 Check for outliers in Numerical Columns

# %%
# Creating the column list of numeric only 
# that will help in Labeling the Graphs while Viewing the Box Plots and other plots 

numeric_columns_name = df.select_dtypes(include = ['number']).columns
for index, num_col_name in enumerate(numeric_columns_name):
    print(index, num_col_name)
# Out:
# 0 Age
# 1 Income
# 2 AdSpend
# 3 ClickThroughRate
# 4 ConversionRate
# 5 WebsiteVisits
# 6 PagesPerVisit
# 7 TimeOnSite
# 8 SocialShares
# 9 EmailOpens
# 10 EmailClicks
# 11 PreviousPurchases
# 12 LoyaltyPoints
# 13 Conversion

# %%
# Determine the number of columns for the subplots grid
n_cols = 4  # Adjust based on how many plots you want in a row
n_rows = (len(numeric_columns_name) + n_cols - 1) // n_cols  # Calculate the number of rows needed

# Creating a figure with subplots, arranged in a grid
fig, ax = plt.subplots(n_rows, n_cols, figsize = (20, 15))
fig.subplots_adjust(hspace = 0.5, wspace = 0.5)  # Adjust spacing between plots

# Loop through each numerical column to create individual box plots
for i, col in enumerate(numeric_columns_name):
    row = i // n_cols
    col_pos = i % n_cols
    sns.boxplot(x = col, data = df, ax = ax[row, col_pos])

# Remove any empty subplots
for j in range(i + 1, n_rows * n_cols):
    fig.delaxes(ax.flatten()[j])

# Adding a title to the figure
fig.suptitle('Box Plots of Numerical Columns', fontsize=16)

plt.show()

# %% [markdown]
# __By Viewing the the results of all the boxplots of the Numeric data we can see that there are no Outliers in the Data.__

# %% [markdown]
# ### <p style="background-color:yellow; font-family:calibri; color:red; font-size:150%; text-align:center; border-radius:50px 50px;">Step 4 | EDA </p>

# %% [markdown]
# > #### __4.1 Univariate Analysis__

# %% [markdown]
# > ##### __4.1.1 Numerical Variables Univariate Analysis__

# %%
# Determine the number of columns for the subplots grid
n_cols = 3  # Adjust based on how many plots you want in a row
n_rows = (len(numeric_columns_name) + n_cols - 1) // n_cols  # Calculate the number of rows needed

# Creating a figure with subplots, arranged in a grid
fig, ax = plt.subplots(n_rows, n_cols, figsize = (20, 15))
fig.subplots_adjust(hspace = 0.5, wspace = 0.5)  # Adjust spacing between plots

# Loop through each numerical column to create individual box plots
for i, col in enumerate(numeric_columns_name):
    row = i // n_cols
    col_pos = i % n_cols
    sns.histplot(x = col, data = df, kde = True, ax = ax[row, col_pos])

# Remove any empty subplots
for j in range(i + 1, n_rows * n_cols):
    fig.delaxes(ax.flatten()[j])

# Adding a title to the figure
fig.suptitle('Box Plots of Numerical Columns', fontsize=16)

plt.show()

# %% [markdown]
# > ##### __4.1.2 Categorical Variables Univariate Analysis__

# %% [markdown]
# >  ___Gender___

# %%
plt.pie(df['Gender'].value_counts(), autopct='%1.1f%%')
plt.title('Gender Distribution')
plt.legend(labels=df['Gender'].value_counts().index)

# %% [markdown]
# Approximately **60.5%** of the individuals in the dataset are female.

# %% [markdown]
# Marketing strategies or campaigns could be adjusted to cater more to female preferences or interests, depending on the product or service being marketed.

# %% [markdown]
# > ___Campaign Channels___

# %%
#plot bar plot for campaign channels
plt.figure(figsize=(12,8))

x = df['CampaignChannel'].value_counts().index
y = df['CampaignChannel'].value_counts().values

sns.barplot(x=x, y=y, palette='viridis')
plt.title('Campaign Channels Distribution')
plt.ylabel('Count')

# Adding values on top of the bars
for i, value in enumerate(y):
    plt.text(i, value + 0.5, f'{value}', ha='center', va='bottom')

plt.show()

# %% [markdown]
# All channels are mostly used but the most used campaign channel is **Referrals** with (1719)

# %% [markdown]
# > ___Campaign Type___

# %%
#plot bar plot for campaign type
plt.figure(figsize=(12,8))

x = df['CampaignType'].value_counts().index
y = df['CampaignType'].value_counts().values

sns.barplot(x=x, y=y, palette='viridis')
plt.title('Campaign Type Distribution')
plt.ylabel('Count')

# Adding values on top of the bars
for i, value in enumerate(y):
    plt.text(i, value + 0.5, f'{value}', ha='center', va='bottom')

plt.show()

# %% [markdown]
# All campaign types are almost equally used but the most used campaign type is **Conversion** with (2077).

# %% [markdown]
# > ___Conversion (Target Variable)___

# %%
print(df['Conversion'].value_counts())
# Conversion (Target Variable) countplot
ax = sns.countplot(data = df, x = 'Conversion', hue = 'Conversion')
# Add data labels on each bar
for container in ax.containers:
    ax.bar_label(container, label_type='edge', fontsize=10, padding=3)
plt.show()
# Out:
# Conversion
# 1    7012
# 0     988
# Name: count, dtype: int64

# %%
# Viewig by percentage of how the conversion is spread across the data

conversion_Value = df['Conversion'].value_counts()
print(conversion_Value)

plt.pie(conversion_Value, labels=['Converted [1]', 'Not Converted [0]'], explode=[0.35, 0.01], autopct='%.f%%', shadow=True)
plt.legend()
plt.show()
# Out:
# Conversion
# 1    7012
# 0     988
# Name: count, dtype: int64

# %% [markdown]
# #### Plotting the Count of 'Conversion'
# > By Looking at the count of the conversion we can see that the data is __highly imbalanced__ and we have to do either __Undersampling or Oversampling__.

# %% [markdown]
# #### __4.2 Bivariate Analysis__

# %% [markdown]
# > ##### __4.2.1 Analyzing Adspend to conversion analysis__

# %%
sns.histplot(data = df, y = 'AdSpend', hue = 'Conversion', kde = True)
# Out:
# <Axes: xlabel='Count', ylabel='AdSpend'>

# %% [markdown]
#     Plotting the distribution of 'AdSpend' by 'Conversion' with KDE
# > _The histogram bars show the frequency of AdSpend values, while the KDE line smooths out The distribution to make patterns more visible._
#
# > _This helps to compare AdSpend Values distributions between the Conversion and identify any significant differences or similarities._

# %% [markdown]
# > ##### __4.2.2 Analyzing Campaign Channnel to Gender__

# %%
ax = sns.countplot(data = df, x = 'CampaignChannel', hue = 'Gender')

# Add data labels on each bar
for container in ax.containers:
    ax.bar_label(container, label_type='edge', fontsize=10, padding=3)
plt.show()
df['CampaignChannel'].value_counts()
# Out:
# CampaignChannel
# Referral        1719
# PPC             1655
# Email           1557
# SEO             1550
# Social Media    1519
# Name: count, dtype: int64

# %% [markdown]
# > _By Viewing the Plot we can see that which Campaign Channel is used the most and also which genger in interacting the most to the Campaign Channel._
#
# > _So we can conclude by seeing the plot that the most frequently used Campaign Cannel is the referral and the females are interacting the most thourghout all the Campaign Channels._

# %% [markdown]
# > ##### __4.2.3 Analyzing Campaign Type to Gender__

# %%
ax = sns.countplot(data = df, x = 'CampaignType', hue = 'Gender')

# Add data labels on each bar
for container in ax.containers:
    ax.bar_label(container, label_type='edge', fontsize=10, padding=3)
plt.show()
df['CampaignType'].value_counts()
# Out:
# CampaignType
# Conversion       2077
# Awareness        1988
# Consideration    1988
# Retention        1947
# Name: count, dtype: int64

# %% [markdown]
# > _This suggests that the company may prioritize conversion campaigns slightly more than others, while awareness, consideration, and retention campaigns are also common but with minor differences in frequency._
#
# > _By Seeing the Plots we can see that the females are interacting more compared to males._

# %% [markdown]
# > ##### __4.2.4 Analyzing Age to Converesion KDE__

# %%
plt.figure(figsize=(20, 10))
ax = sns.kdeplot(data=df, x='Age', hue='Conversion', fill=True, palette='Set2', common_norm=False, alpha=0.6)
plt.title('Age Distribution by Conversion', fontsize=16)
plt.xlabel('Age', fontsize=14)
plt.ylabel('Density', fontsize=14)
plt.legend(title='Conversion', labels=['Not Converted', 'Converted'], fontsize=12)

plt.grid(False)
plt.legend(title='Conversion', labels=['Not Converted', 'Converted'], fontsize=12)
plt.show()

# %% [markdown]
# From the above graph we can say in age range 35-45 and 60-70 Conversion is low.
# <p> so need to design marketing campaign accordingly.

# %% [markdown]
# > ##### __4.2.5 Analyzing Previous purchases impact on conversion__

# %%
# barplot visualization
ax = sns.barplot(data=df, x='Conversion', y='PreviousPurchases' , hue= 'Conversion')
plt.title('Conversion by Previous Purchases')

# Add data labels on each bar
for container in ax.containers:
    ax.bar_label(container, label_type='edge', fontsize=10, padding=3)

plt.show()

# %% [markdown]
# The individuals with more previous purchases seems to result in a higher conversion.

# %% [markdown]
# > ##### __4.2.6 Analyzing Loyalty Points impact on conversion__

# %%
ax = sns.barplot(data=df, x='Conversion', y='LoyaltyPoints', hue= 'Conversion')
plt.title('Conversion by Loyalty Points')

# Add data labels on each bar
for container in ax.containers:
    ax.bar_label(container, label_type='edge', fontsize=10, padding=3)

plt.show()

# %% [markdown]
# Higher loyalty points results to more conversion (1)

# %% [markdown]
# > ##### __4.2.7 Analyzing Campaign Channel to Conversion__

# %%
plt.figure(figsize=(12, 8))
ax = sns.countplot(data=df, x='CampaignChannel', hue='Conversion', palette='Set1')


# Add data labels on each bar
for container in ax.containers:
    ax.bar_label(container, label_type='edge', fontsize=10, padding=3)

plt.title('Conversion by Marketing Channel')
plt.xlabel('Marketing Channel')
plt.ylabel('Count')
plt.grid(True)
plt.show()

# %% [markdown]
# 'Referral' leads the marketing channels on conversion with (1518)

# %% [markdown]
# > ##### __4.2.8 Analyzing Campaign Type to Convertion__

# %%
plt.figure(figsize=(12, 8))
ax = sns.countplot(data=df, x='CampaignType', hue='Conversion', palette='Set1')
plt.title('Conversion by Campaign Type')
plt.xlabel('Campaign Type')
plt.ylabel('Count')

# Add data labels on each bar
for container in ax.containers:
    ax.bar_label(container, label_type='edge', fontsize=10, padding=3)

plt.grid(True)
plt.show()

# %% [markdown]
# > #### __4.3 Analysis of the Campaign Type, Gender, Campaign Channel and the Conversion Data Columns__

# %%
# Creating a Cat Plot of the Campaign Type, Gender, Campaign Channel and the Conversion Data Columns 

g = sns.catplot(
    data=df,
    x = 'CampaignType',
    hue = 'Gender',
    col = 'CampaignChannel',  
    row = 'Conversion',
    kind = 'count',
    height = 4,
    aspect = 0.9
)

# %% [markdown]
#      Creating a multi-faceted categorical plot
# > __This plot visualizes the distribution of different 'CampaignType' categories, split by gender.__
#
# > __The plot is further broken down by 'CampaignChannel' and 'Conversion' status.__
#
# #### __Key Inferences__:
# ##### 1. **Campaign Type Preferences by Gender**:
# > - By examining each facet, we can identify which campaign types are more popular among different genders.
#
# > - For instance, if a particular campaign type shows higher counts for one gender, it indicates a preference or higher engagement from that gender.
#
# ##### 2. **Channel Effectiveness**:
# > - The 'col' parameter splits the data by 'CampaignChannel', allowing us to observe how different channels perform for each campaign type.
#
# > - By comparing the counts, we can infer which channels are most effective for different campaign types and genders.
#
# ##### 3. **Conversion Rates**:
# > - The 'row' parameter divides the data by 'Conversion' status, highlighting the effectiveness of each campaign type and channel in driving conversions.
#
# > - High counts in the 'Conversion = 1' row suggest that certain campaign types and channels are more successful in converting users, potentially revealing gender-specific conversion patterns.
#
# ##### 4. **Strategic Insights**:
# > - This plot provides a comprehensive view of how campaign types are distributed across channels and gender, and how they relate to conversion outcomes.
#
# > - These insights can be used to tailor future marketing strategies by focusing on the most effective campaign types and channels for each gender.

# %% [markdown]
# ### <p style="background-color:yellow; font-family:calibri; color:red; font-size:150%; text-align:center; border-radius:50px 50px;">Step 5 | Feature Engineering </p>

# %% [markdown]
# > ##### __5.1 Seperate Data in Features and Target__

# %%
#Separate Features and target
X = df.drop('Conversion', axis= 1) # X is Features
Y = df['Conversion']   # Y is Target

# %% [markdown]
# > ##### __5.1.1 seperate features in numeric and categorical columns list for Scaling and Encoding__

# %%
num_col = X.select_dtypes(['number']).columns #numeric columns list for Scaling
cat_col = X.select_dtypes(include= 'object').columns #categorical columns list for Encoding
num_col, cat_col
# Out:
# (Index(['Age', 'Income', 'AdSpend', 'ClickThroughRate', 'ConversionRate',
#         'WebsiteVisits', 'PagesPerVisit', 'TimeOnSite', 'SocialShares',
#         'EmailOpens', 'EmailClicks', 'PreviousPurchases', 'LoyaltyPoints'],
#        dtype='object'),
#  Index(['Gender', 'CampaignChannel', 'CampaignType'], dtype='object'))

# %% [markdown]
# > #### __5.2 Scaling of numeric columns of feature__

# %%
# Scaling the numerical columns using StandardScaler
scaler = StandardScaler()
X[num_col] = scaler.fit_transform(X[num_col])

# %% [markdown]
# > #### __5.3 Encoding Categorical columns of features__

# %%
# Apply Label Encoding to categorical columns
label_encoders = {}
for col in cat_col:
    le = LabelEncoder()
    X[col] = le.fit_transform(X[col])
    label_encoders[col] = le

# %% [markdown]
# ## Converisons Happened
# | __Variable__ | __Description__ |
# |     :---      |       :---      |
# | __Gender__ | <br><br> 0: Female <br> 1: Male |
# | __CampaignChannel__ | <br><br> 0: Email <br> 1: PPC <br> 2: Referral <br> 3: SEO <br> 4: Social Media |
# | __CampaignType__ | <br><br> 0: Awareness <br> 1: Consideration <br> 2: Conversion <br> 3: Retention |

# %% [markdown]
# > #### __5.4 Correlation Metrics__

# %%
# Calculating the correlation matrix for the DataFrame
corr = df.select_dtypes(['number']).corr()

# Creating a heatmap to visualize the correlation matrix
plt.figure(figsize=(10, 5))
sns.heatmap(
    corr, 
    annot = True,           # Annotates each cell with the correlation coefficient
    fmt = '.2f',            # Formats the annotations to 2 decimal places
    linewidths = 0.725,     # Adds a line between cells
    linecolor = 'white',    # Color of the lines between cells
    mask = np.triu(corr),   # Masks the upper triangle of the heatmap to avoid redundancy
    cmap = 'Blues'          # Color map for the heatmap
)
plt.show()

# %% [markdown]
# > __- The heatmap shows the correlation coefficients between features in the dataset.__
#
# > __- Positive values indicate a positive correlation, meaning as one feature increases, the other tends to increase as well which will raise the issue of multi collinearity.__
#
# > __- Negative values indicate a negative correlation, meaning as one feature increases, the other tends to decrease.__
#
# > __- A correlation close to 1 or -1 indicates a strong relationship between the features, while a correlation close to 0 indicates a weak relationship.__
#
# > __- The mask is used to hide the upper triangle of the heatmap, as the correlation matrix is symmetric, and this helps to reduce redundancy in the visualization.__
#
# > __- Features with low or near-zero correlations with others indicate independence.__
#
# > __- These features might be good candidates for inclusion in the model as they contribute unique information.__

# %% [markdown]
# > #### __5.5 Handling Imbalance__

# %% [markdown]
# > __When seen the Conversion Column in the Data Frame we Saw that the converted [1] is more and.__
#
# > __non-converted [0] is less to be precise the split is 88 % to 12 % from which we can conclude that the data is highly Imbalance.__
#
# > __Thus, have decided to go forward with Oversampling, because when performing undersampling the converted [1] data will lose around 6000 datapoints which is not a feasible chooice because it might contain many information that te data could learn and predict from and removing those data will highly impact the Learning of the data .__

# %% [markdown]
# > ##### __5.5.1 Techniques can be used to handle Imbalance__

# %% [markdown]
# #### SMOTE (Synthetic Minority Over-sampling Technique):
#
# > SMOTE is used to address the problem of imbalanced datasets by generating synthetic samples of the minority class. It works by selecting a minority class instance, finding its nearest neighbors, and then generating new instances along the line segments connecting the minority instance to its neighbors.
#
# #### Tomek Links:
#
# > Tomek Links is a data cleaning method that identifies and removes pairs of instances from the dataset that are close to each other but belong to different classes. These pairs, known as Tomek links, often reside near the decision boundary, and their removal can help in making the boundary clearer.
#
# #### SMOTETomek
#
# > It combines these two approaches to first apply SMOTE to increase the number of minority class samples, and then use Tomek Links to remove noisy or borderline samples. This combination helps in balancing the dataset while also cleaning it, leading to potentially better model performance, especially in classification tasks.
#
# > __So we are Going ahead with the combination of Oversampling and Tomek which is SMOTETomek.__

# %%
ost = SMOTETomek()    # Making the object of the SMOTETomek Class

X_osto, y_osto = ost.fit_resample(X, Y)

# %%
# Checking the Shape of X Columns and y Columns

print(f'Shape of X : {X_osto.shape}')
print(f'Shape of y : {y_osto.shape}')
# Out:
# Shape of X : (14020, 16)
# Shape of y : (14020,)

# %%
y_osto.value_counts()
# Out:
# Conversion
# 1    7010
# 0    7010
# Name: count, dtype: int64

# %% [markdown]
# > #### __5.6 Split Data into Train and test__

# %%
# Splitting the Data into Train and Test Split

X_train, X_test, y_train, y_test = train_test_split(X_osto, y_osto, test_size = 0.2, random_state = 42, stratify = y_osto)

# %%
# Checking the Shapes of the Splits

print(f'Shape of X_train : {X_train.shape}')
print(f'Shape of X_test : {X_test.shape}')
print(f'Shape of y_train : {y_train.shape}')
print(f'Shape of y-test : {y_test.shape}')
# Out:
# Shape of X_train : (11216, 16)
# Shape of X_test : (2804, 16)
# Shape of y_train : (11216,)
# Shape of y-test : (2804,)

# %% [markdown]
# ### <p style="background-color:yellow; font-family:calibri; color:red; font-size:150%; text-align:center; border-radius:50px 50px;">Step 6  | Model Selection </p>

# %% [markdown]
# > #### __6.1 Model Evaluation Function__

# %%
#Define Model Evaluation Function
def model_evaluation(model, X_train = X_train, X_test = X_test, y_train = y_train, y_test = y_test, k = 5 ): #model, traing-testing data and K as parameters
    cv_scores = cross_val_score(model, X_train, y_train, cv=k)  # use cross validation for training
    print(f"Cross-Validation Scores (K={k}): {cv_scores}")      # print the cross validation scores
    print(f"Mean Accuracy: {cv_scores.mean():.2f}")             # print the mean accuracy
    print(f"Standard Deviation: {cv_scores.std():.2f}")         # print the standard deviation in the cross validation scores

    model.fit(X_train, y_train)                                 # fit traing data in model
    YP = model.predict(X_test)                                  # predict using test data
    
    # Create a 2x2 grid for subplots
    fig, ax = plt.subplots(2, 2, figsize=(15, 10))
    fig.tight_layout(pad=5.0)

    # AX Top-Left: Confusion Matrix
    cm = confusion_matrix(y_test, YP)
    sns.heatmap(cm, cmap='Blues', annot=True, fmt='', linewidths=0.5, ax=ax[0, 0])
    ax[0, 0].set_xlabel('Predicted labels', fontsize=14)
    ax[0, 0].set_ylabel('Actual labels', fontsize=14)
    ax[0, 0].set_title('Confusion Matrix', fontsize=18)
    ax[0, 0].xaxis.set_ticklabels(['0', '1'])
    ax[0, 0].yaxis.set_ticklabels(['0', '1'])

    # AX Top-Right: Classification Report
    cr = pd.DataFrame(classification_report(y_test, YP, digits=3, output_dict=True)).T
    cr.drop(columns='support', inplace=True)
    sns.heatmap(cr, cmap='Blues', annot=True, fmt='0.3f', linewidths=0.5, ax=ax[0, 1])
    ax[0, 1].set_title('Classification Report', fontsize=18)

    # AX Bottom-Left: ROC Curve
    fpr, tpr, thresholds = roc_curve(y_test, YP)
    roc_auc = auc(fpr, tpr)

    ax[1, 0].plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
    ax[1, 0].plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    ax[1, 0].set_xlim([0.0, 1.0])
    ax[1, 0].set_ylim([0.0, 1.05])
    ax[1, 0].set_xlabel('False Positive Rate')
    ax[1, 0].set_ylabel('True Positive Rate')
    ax[1, 0].set_title('ROC Curve', fontsize=18)
    ax[1, 0].legend(loc="lower right")

    # AX Bottom-Right: Precision-Recall Curve
    precision, recall, thresholds = precision_recall_curve(y_test, YP)
    avg_precision = average_precision_score(y_test, YP)

    ax[1, 1].plot(recall, precision, color='b', lw=2, label=f'Precision-Recall curve (AP = {avg_precision:.2f})')
    ax[1, 1].set_xlabel('Recall')
    ax[1, 1].set_ylabel('Precision')
    ax[1, 1].set_title('Precision-Recall Curve', fontsize=18)
    ax[1, 1].legend(loc="lower left")

    plt.show()

    return accuracy_score(y_test, YP), f1_score(y_test, YP)     #return accuracy and f1_score of the model

# %%
# list for comparing models accuracy and f1_score
Model_name = ["Logistic Regression", "SVM", "Decision Tree", "Random Forest", "Gradient Boosing", "Ada Boost", "Bagging Classifier"]
Model_acc = []
Model_f1 = []

# %% [markdown]
# > #### __6.2 Model Building__

# %% [markdown]
# > ##### __6.2.1 Logistic Regression__

# %%
LR = LogisticRegression()
LR_acc, LR_f1 = model_evaluation(LR)
Model_acc.append(LR_acc)
Model_f1.append(LR_f1)
# Out:
# Cross-Validation Scores (K=5): [0.74643494 0.74765938 0.73874276 0.74721355 0.73785109]
# Mean Accuracy: 0.74
# Standard Deviation: 0.00

# %% [markdown]
# > ##### __6.2.2 Support Vector Machine__

# %%
svc = SVC()
svc_acc, svc_f1 = model_evaluation(svc)
Model_acc.append(svc_acc)
Model_f1.append(svc_f1)
# Out:
# Cross-Validation Scores (K=5): [0.83333333 0.82701739 0.82032992 0.82880071 0.8230049 ]
# Mean Accuracy: 0.83
# Standard Deviation: 0.00

# %% [markdown]
# > ##### __6.2.3 Decision Tree__

# %%
DT = DecisionTreeClassifier()
DT_acc, DT_f1 = model_evaluation(DT)
Model_acc.append(DT_acc)
Model_f1.append(DT_f1)
# Out:
# Cross-Validation Scores (K=5): [0.82932264 0.82790905 0.81943825 0.84752564 0.83727151]
# Mean Accuracy: 0.83
# Standard Deviation: 0.01

# %% [markdown]
# > ##### __6.2.4 Random Forest__

# %%
rf = RandomForestClassifier()
rf_acc, rf_f1 = model_evaluation(rf)
Model_acc.append(rf_acc)
Model_f1.append(rf_f1)
# Out:
# Cross-Validation Scores (K=5): [0.94073084 0.92599198 0.93847526 0.93267945 0.9362461 ]
# Mean Accuracy: 0.93
# Standard Deviation: 0.01

# %% [markdown]
# > ##### __6.2.5 Gradient Boosting__

# %%
GB = GradientBoostingClassifier()
GB_acc, GB_f1 = model_evaluation(GB)
Model_acc.append(GB_acc)
Model_f1.append(GB_f1)
# Out:
# Cross-Validation Scores (K=5): [0.90240642 0.88452965 0.88987963 0.88497548 0.89835042]
# Mean Accuracy: 0.89
# Standard Deviation: 0.01

# %% [markdown]
# > ##### __6.2.6 AdaBoost__

# %%
AB = AdaBoostClassifier()
AB_acc, AB_f1 = model_evaluation(AB)
Model_acc.append(AB_acc)
Model_f1.append(AB_f1)
# Out:
# Cross-Validation Scores (K=5): [0.81417112 0.80695497 0.82523406 0.81230495 0.82612572]
# Mean Accuracy: 0.82
# Standard Deviation: 0.01

# %% [markdown]
# >##### __6.2.7 Bagging Classifier__

# %%
Bag = BaggingClassifier()
Bag_acc, Bag_f1 = model_evaluation(Bag)
Model_acc.append(Bag_acc)
Model_f1.append(Bag_f1)
# Out:
# Cross-Validation Scores (K=5): [0.88903743 0.89121712 0.89790459 0.88943379 0.89790459]
# Mean Accuracy: 0.89
# Standard Deviation: 0.00

# %% [markdown]
# > #### __6.3 Model Comparision__

# %% [markdown]
# > ##### __6.3.1 Model Accuracy Comparison__

# %%
ax = sns.barplot(x=Model_name, y=Model_acc, palette='viridis')
plt.title('Model Accuracy')
plt. xticks(rotation=45)

# Add data labels on each bar
for container in ax.containers:
    ax.bar_label(container, label_type='edge', fontsize=10, padding=3)
plt.show()

# %% [markdown]
# > ##### __6.3.2 Model F1 Score Comparison__

# %%
ax = sns.barplot(x = Model_name, y = Model_f1, palette='viridis')
plt.title('Model F1_score')
plt. xticks(rotation=45)

# Add data labels on each bar
for container in ax.containers:
    ax.bar_label(container, label_type='edge', fontsize=10, padding=3)
plt.show()

# %% [markdown]
# > __From all the models  RandomForest has higher accuracy (95%), highest f1 score(95%), highest precision (94.1%), highst recall (96%)__
#
# > __so the best model is Random Forest__
#
# > __we are not hyperparameter tune RandomForest as the accuracy is already high and it could lead to overfit model.__

# %% [markdown]
# ### <p style="background-color:yellow; font-family:calibri; color:red; font-size:150%; text-align:center; border-radius:50px 50px;">Step 7 | Save Model
#  </p>

# %%
joblib.dump(rf, "model.pkl")            # save Random Forest model for Deployment
joblib.dump(scaler, 'scaler.pkl')       # save scaler for Deployment
# Out:
# ['scaler.pkl']

# %% [markdown]
# ### <p style="background-color:yellow; font-family:calibri; color:red; font-size:150%; text-align:center; border-radius:50px 50px;">Step 8 | Model Deployment
# </p>

# %%
import streamlit as st
import joblib
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# Load the trained model, scaler, and label encoders
model = joblib.load('model.pkl')
scaler = joblib.load('scaler.pkl')

def predict_conversion(input_data):
    # List of numeric columns
    numeric_columns = ['Age', 'Income', 'AdSpend', 'ClickThroughRate', 'ConversionRate',
                       'WebsiteVisits', 'PagesPerVisit', 'TimeOnSite', 'SocialShares',
                       'EmailOpens', 'EmailClicks', 'PreviousPurchases', 'LoyaltyPoints']
    # Scaling numerical features
    input_data[numeric_columns] = scaler.transform(input_data[numeric_columns])
    
    # Make prediction
    prediction = model.predict(input_data)
    return 'Can Be Convert' if prediction[0] == 1 else 'Can Not Convert'

# Streamlit App
st.title("Marketing Campaign Conversion Prediction")

# User input form
age = st.number_input('Age', min_value=18, max_value=100)
gender = st.selectbox('Gender', ['Male', 'Female'])
income = st.number_input('Income', min_value=10000, max_value=200000)
campaign_channel = st.selectbox('Campaign Channel', ['Social Media', 'Email', 'PPC', 'SEO', 'Referral'])
campaign_type = st.selectbox('Campaign Type', ['Awareness', 'Retention', 'Conversion', 'Consideration'])
ad_spend = st.number_input('Ad Spend', min_value=0.0, max_value=10000.0)
click_through_rate = st.number_input('Click Through Rate', min_value=0.0, max_value=1.0)
conversion_rate = st.number_input('Conversion Rate', min_value=0.0, max_value=1.0)
website_visits = st.number_input('Website Visits', min_value=0)
pages_per_visit = st.number_input('Pages Per Visit', min_value=0.0, max_value=20.0)
time_on_site = st.number_input('Time on Site (minutes)', min_value=0.0, max_value=60.0)
social_shares = st.number_input('Social Shares', min_value=0)
email_opens = st.number_input('Email Opens', min_value=0)
email_clicks = st.number_input('Email Clicks', min_value=0)
previous_purchases = st.number_input('Previous Purchases', min_value=0)
loyalty_points = st.number_input('Loyalty Points', min_value=0)

# Mapping categorical variables
gender_mapping = {'Male': 0, 'Female': 1}
channel_mapping = {'Email': 0, 'PPC': 1, 'Referral': 2, 'SEO': 3, 'Social Media': 4}
campaign_type_mapping = {'Awareness': 0, 'Retention': 3, 'Consideration': 1, 'Conversion': 2}

gender = gender_mapping[gender]
campaign_channel = channel_mapping[campaign_channel]
campaign_type = campaign_type_mapping[campaign_type]

# Collecting input data as a single-row DataFrame
input_data = pd.DataFrame({
    "Age": [age],
    "Gender": [gender],
    "Income": [income],
    "CampaignChannel": [campaign_channel],
    "CampaignType": [campaign_type],
    "AdSpend": [ad_spend],
    "ClickThroughRate": [click_through_rate],
    "ConversionRate": [conversion_rate],
    "WebsiteVisits": [website_visits],
    "PagesPerVisit": [pages_per_visit],
    "TimeOnSite": [time_on_site],
    "SocialShares": [social_shares],
    "EmailOpens": [email_opens],
    "EmailClicks": [email_clicks],
    "PreviousPurchases": [previous_purchases],
    "LoyaltyPoints": [loyalty_points]
})

# Predict button
if st.button('Predict Conversion'):
    result = predict_conversion(input_data)
    st.write(f'The prediction is: {result}')

# %% [markdown]
# >##### We can run the script in py format in Command Prompt using streamlit run filename.py
